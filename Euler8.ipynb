# %%
def euler8(num):
    
    milalg = "..."
    
    maiorseq = '0'
    maiormult = 0
    
    for n in range(num, 1001):
        ini = n - num
        seq = milalg[ini : n]
        mult = 1
        for i in range(num):
            seqint = int(seq[i])
            mult *= seqint
        if mult > maiormult:
            maiormult = mult
            maiorseq = seq
    print(maiorseq)
    print(maiormult)

# %%
euler8(13)
# Out:
# 5576689664895
# 23514624000
